# %%
from plotting.wasserstein_distance_clustering import pairwise_wasserstein
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from plotting.wasserstein_distance_clustering import pairwise_wasserstein
#
# ModuleNotFoundError: No module named 'plotting'

# %%
# create an ambient grid summarizing the "mutations" and distribution of the gradients or something that applies in the latent space X the dimensionslity

# %%
import scripts

# %%
import utils

# %%
import plotting
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import plotting
#
# ModuleNotFoundError: No module named 'plotting'
